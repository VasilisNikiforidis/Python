# %%
"""
If a player's guess is less than 1 or greater than 100, say "OUT OF BOUNDS"
On a player's first turn, if their guess is
within 10 of the number, return "WARM!"
further than 10 away from the number, return "COLD!"
On all subsequent turns, if a guess is
closer to the number than the previous guess return "WARMER!"
farther from the number than the previous guess, return "COLDER!"
When the player's guess equals the number, tell them they've guessed correctly and how many guesses it took!
"""


print("WELCOME TO GUESS ME!")
print("I'm thinking of a number between 1 and 100")
print("If your guess is more than 10 away from my number, I'll tell you you're COLD")
print("If your guess is within 10 of my number, I'll tell you you're WARM")
print("If your guess is farther than your most recent guess, I'll say you're getting COLDER")
print("If your guess is closer than your most recent guess, I'll say you're getting WARMER")
print("LET'S PLAY!")

from random import randint
num=randint(1,100)
guesses=[]
count=0
guess=int(input('Take a guess!\n'))
while guess<1 or guess >100:
    print('OUT OF BOUNDS')
    guesses.append(guess)
    guess=int(input('Take another guess!\n'))
    count+=1

while guess>=1 and guess<=100 and len(guesses)<=count:
    guesses.append(guess)
    if guess==num:
        print('You guessed correctly and it took you only {} guess!'.format(len(guesses)))
    elif abs(num-guess)<=10:
        print('WARM!')
    else:
        print('COLD!')

while guess>=1 and guess<=100 and len(guesses)>count:
    guess=int(input('Take another guess!\n'))
    guesses.append(guess)
    while guess<1 or guess >100:
        print('OUT OF BOUNDS')
        guess=int(input('Take another guess!\n'))
        guesses.append(guess)
        pass
    if abs(num-guess)<=abs(num-guesses[-2]) and abs(num-guess)!=0:
        print('WARMER!')
    elif abs(num-guess)>abs(num-guesses[-2]):
        print('COLDER!')
    elif guess==num:
        print('You guessed correctly and it took you only {} guesses!'.format(len(guesses)))
        break
# Out:
# WELCOME TO GUESS ME!
# I'm thinking of a number between 1 and 100
# If your guess is more than 10 away from my number, I'll tell you you're COLD
# If your guess is within 10 of my number, I'll tell you you're WARM
# If your guess is farther than your most recent guess, I'll say you're getting COLDER
# If your guess is closer than your most recent guess, I'll say you're getting WARMER
# LET'S PLAY!
# Take a guess!
# -15
# OUT OF BOUNDS
# Take another guess!
# 107
# OUT OF BOUNDS
# Take another guess!
# 25
# COLD!
# Take another guess!
# 50
# WARMER!
# Take another guess!
# 55
# WARMER!
# Take another guess!
# 65
# WARMER!
# Take another guess!
# 75
# WARMER!
# Take another guess!
# 85
# WARMER!
# Take another guess!
# 95
# COLDER!
# Take another guess!
# 80
# WARMER!
# Take another guess!
# 82
# WARMER!
# Take another guess!
# 83
# WARMER!
# Take another guess!
# 84
# You guessed correctly and it took you only 13 guesses!
